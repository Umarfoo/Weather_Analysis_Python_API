# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Spliting "cities" list into sub lists of 50 cities
n = 50   
city_subset = [cities[i * n:(i + 1) * n] for i in range((len(cities) + n - 1) // n )]

# %%
units = "imperial"

city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

analysis_date = time.strftime("%m/%d/%Y", time.gmtime())

print ("Beginning Data Retrieval")   
print ("-----------------------------")


for citi in city_subset:
    
    sett = city_subset.index(citi)
    
    for city in citi:
        
        query_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units={units}"
        response = requests.get(query_url)
        response_json = response.json()

        try:
            print(f"Processing Record {citi.index(city)} of Set {sett} | {city}")
            
            city = response_json["name"]
            city_name.append(city)

            cloud = response_json["clouds"]["all"]
            cloudiness.append(cloud)

            country_name = response_json["sys"]["country"]
            country.append(country_name)

            time = response_json["dt"]
            date.append(time)

            humid = response_json["main"]["humidity"]
            humidity.append(humid)

            lati = response_json["coord"]["lat"]
            lat.append(lati)

            long = response_json["coord"]["lon"]
            lng.append(long)

            max_t = response_json["main"]["temp_max"]
            max_temp.append(max_t)

            wind_s = response_json["wind"]["speed"]
            wind_speed.append(wind_s)
            
        except KeyError:
            print(f'{city} city not found. Skipping...')

print("-----------------------------")
print("Data Retrieval Complete")     
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 0 | khatanga
# Processing Record 1 of Set 0 | fort atkinson
# Processing Record 2 of Set 0 | vaitupu
# vaitupu city not found. Skipping...
# Processing Record 3 of Set 0 | port alfred
# Processing Record 4 of Set 0 | butaritari
# Processing Record 5 of Set 0 | cape town
# Processing Record 6 of Set 0 | ushuaia
# Processing Record 7 of Set 0 | norwich
# Processing Record 8 of Set 0 | albany
# Processing Record 9 of Set 0 | zhigansk
# Processing Record 10 of Set 0 | busselton
# Processing Record 11 of Set 0 | dikson
# Processing Record 12 of Set 0 | port elizabeth
# Processing Record 13 of Set 0 | lebu
# Processing Record 14 of Set 0 | burnie
# Processing Record 15 of Set 0 | cayenne
# Processing Record 16 of Set 0 | mar del plata
# Processing Record 17 of Set 0 | rikitea
# Processing Record 18 of Set 0 | kaitangata
# Processing Record 19 of Set 0 | saint-philippe
# Processing Record 20 of Set 0 | codrington
# Processing Record 21 of Set 0 | plastun
# Processing Record 22 of Set 0 | ancud
# Processing Record 23 of Set 0 | longyearbyen
# Processing Record 24 of Set 0 | gravdal
# Processing Record 25 of Set 0 | hot springs
# Processing Record 26 of Set 0 | santa maria
# Processing Record 27 of Set 0 | lorengau
# Processing Record 28 of Set 0 | vaini
# Processing Record 29 of Set 0 | puerto ayora
# Processing Record 30 of Set 0 | sao joao da barra
# Processing Record 31 of Set 0 | provideniya
# Processing Record 32 of Set 0 | jamestown
# Processing Record 33 of Set 0 | manzil salim
# Processing Record 34 of Set 0 | taolanaro
# taolanaro city not found. Skipping...
# Processing Record 35 of Set 0 | imbituva
# Processing Record 36 of Set 0 | casambalangan
# Processing Record 37 of Set 0 | fairbanks
# Processing Record 38 of Set 0 | torbay
# Processing Record 39 of Set 0 | macia
# Processing Record 40 of Set 0 | barrow
# Processing Record 41 of Set 0 | hilo
# Processing Record 42 of Set 0 | katsuura
# Processing Record 43 of Set 0 | amderma
# amderma city not found. Skipping...
# Processing Record 44 of Set 0 | izazi
# Processing Record 45 of Set 0 | ola
# Processing Record 46 of Set 0 | nikolskoye
# Processing Record 47 of Set 0 | kupang
# Processing Record 48 of Set 0 | zeya
# Processing Record 49 of Set 0 | saskylakh
# Processing Record 0 of Set 1 | ribeira grande
# Processing Record 1 of Set 1 | desaguadero
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | vega de alatorre
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | saleaula
# saleaula city not found. Skipping...
# Processing Record 9 of Set 1 | hasanabad
# Processing Record 10 of Set 1 | aklavik
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | belushya guba
# belushya guba city not found. Skipping...
# Processing Record 14 of Set 1 | luderitz
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | samos
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | nyurba
# Processing Record 19 of Set 1 | rio de jesus
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | pisco
# Processing Record 22 of Set 1 | palabuhanratu
# palabuhanratu city not found. Skipping...
# Processing Record 23 of Set 1 | sentyabrskiy
# sentyabrskiy city not found. Skipping...
# Processing Record 24 of Set 1 | ahipara
# Processing Record 25 of Set 1 | padang
# Processing Record 26 of Set 1 | oussouye
# Processing Record 27 of Set 1 | baykit
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | athens
# Processing Record 30 of Set 1 | copainala
# Processing Record 31 of Set 1 | erice
# Processing Record 32 of Set 1 | imeni babushkina
# Processing Record 33 of Set 1 | thunder bay
# Processing Record 34 of Set 1 | hamilton
# Processing Record 35 of Set 1 | aguas formosas
# Processing Record 36 of Set 1 | arawa
# Processing Record 37 of Set 1 | husavik
# Processing Record 38 of Set 1 | vitim
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | jardim
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | macaboboni
# macaboboni city not found. Skipping...
# Processing Record 45 of Set 1 | cootamundra
# Processing Record 46 of Set 1 | bud
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | nunoa
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 0 of Set 2 | bethel
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | weligama
# Processing Record 3 of Set 2 | poya
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | nanakuli
# Processing Record 9 of Set 2 | sistranda
# Processing Record 10 of Set 2 | terney
# Processing Record 11 of Set 2 | tsaratanana
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | yar-sale
# Processing Record 14 of Set 2 | tokmak
# Processing Record 15 of Set 2 | mapiri
# Processing Record 16 of Set 2 | mount darwin
# Processing Record 17 of Set 2 | manaure
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | korla
# Processing Record 21 of Set 2 | belur
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | bubaque
# Processing Record 24 of Set 2 | broken hill
# Processing Record 25 of Set 2 | meulaboh
# Processing Record 26 of Set 2 | brae
# Processing Record 27 of Set 2 | tuatapere
# Processing Record 28 of Set 2 | nguiu
# nguiu city not found. Skipping...
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | shiyan
# Processing Record 31 of Set 2 | shache
# Processing Record 32 of Set 2 | turukhansk
# Processing Record 33 of Set 2 | straumen
# Processing Record 34 of Set 2 | awbari
# Processing Record 35 of Set 2 | bambous virieux
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | port hedland
# Processing Record 38 of Set 2 | neiafu
# Processing Record 39 of Set 2 | burica
# burica city not found. Skipping...
# Processing Record 40 of Set 2 | monterey
# Processing Record 41 of Set 2 | ngunguru
# Processing Record 42 of Set 2 | kishtwar
# Processing Record 43 of Set 2 | egvekinot
# Processing Record 44 of Set 2 | ushtobe
# Processing Record 45 of Set 2 | ayan
# Processing Record 46 of Set 2 | victoria
# Processing Record 47 of Set 2 | la ronge
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | abu samrah
# Processing Record 0 of Set 3 | camana
# Processing Record 1 of Set 3 | do gonbadan
# Processing Record 2 of Set 3 | nata
# Processing Record 3 of Set 3 | gushikawa
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | marcona
# marcona city not found. Skipping...
# Processing Record 6 of Set 3 | hambantota
# Processing Record 7 of Set 3 | westport
# Processing Record 8 of Set 3 | fort nelson
# Processing Record 9 of Set 3 | gladstone
# Processing Record 10 of Set 3 | businga
# Processing Record 11 of Set 3 | katete
# Processing Record 12 of Set 3 | thinadhoo
# Processing Record 13 of Set 3 | ciudad bolivar
# Processing Record 14 of Set 3 | college
# Processing Record 15 of Set 3 | beloha
# Processing Record 16 of Set 3 | rezh
# Processing Record 17 of Set 3 | sitka
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | balsas
# Processing Record 21 of Set 3 | ustikolina
# Processing Record 22 of Set 3 | albion
# Processing Record 23 of Set 3 | saint anthony
# Processing Record 24 of Set 3 | cabcaben
# Processing Record 25 of Set 3 | stromness
# Processing Record 26 of Set 3 | arrecife
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | bluff
# Processing Record 29 of Set 3 | palmerston
# Processing Record 30 of Set 3 | barentsburg
# barentsburg city not found. Skipping...
# Processing Record 31 of Set 3 | bandundu
# Processing Record 32 of Set 3 | shingu
# Processing Record 33 of Set 3 | tsihombe
# tsihombe city not found. Skipping...
# Processing Record 34 of Set 3 | ligayan
# Processing Record 35 of Set 3 | mungaoli
# Processing Record 36 of Set 3 | longyan
# Processing Record 37 of Set 3 | verkhnevilyuysk
# Processing Record 38 of Set 3 | vangaindrano
# Processing Record 39 of Set 3 | namatanai
# Processing Record 40 of Set 3 | lodja
# Processing Record 41 of Set 3 | aswan
# Processing Record 42 of Set 3 | tingo maria
# Processing Record 43 of Set 3 | meyungs
# meyungs city not found. Skipping...
# Processing Record 44 of Set 3 | khani
# Processing Record 45 of Set 3 | galle
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | naze
# Processing Record 48 of Set 3 | itanhaem
# Processing Record 49 of Set 3 | tual
# Processing Record 0 of Set 4 | springfield
# Processing Record 1 of Set 4 | calama
# Processing Record 2 of Set 4 | atar
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | mizan teferi
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | port-de-paix
# port-de-paix city not found. Skipping...
# Processing Record 8 of Set 4 | nianzishan
# Processing Record 9 of Set 4 | khambi-irze
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | kutum
# Processing Record 12 of Set 4 | boyuibe
# Processing Record 13 of Set 4 | mixtequilla
# mixtequilla city not found. Skipping...
# Processing Record 14 of Set 4 | dinagat
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | antofagasta
# Processing Record 17 of Set 4 | mys shmidta
# mys shmidta city not found. Skipping...
# Processing Record 18 of Set 4 | asau
# Processing Record 19 of Set 4 | dandong
# Processing Record 20 of Set 4 | nantucket
# Processing Record 21 of Set 4 | illoqqortoormiut
# illoqqortoormiut city not found. Skipping...
# Processing Record 22 of Set 4 | malwan
# malwan city not found. Skipping...
# Processing Record 23 of Set 4 | ponta delgada
# Processing Record 24 of Set 4 | dongsheng
# Processing Record 25 of Set 4 | opuwo
# Processing Record 26 of Set 4 | tazovskiy
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | kochki
# Processing Record 29 of Set 4 | along
# Processing Record 30 of Set 4 | pringsewu
# Processing Record 31 of Set 4 | manturovo
# Processing Record 32 of Set 4 | linares
# Processing Record 33 of Set 4 | severnoye
# Processing Record 34 of Set 4 | rock sound
# Processing Record 35 of Set 4 | guerrero negro
# Processing Record 36 of Set 4 | baruun-urt
# Processing Record 37 of Set 4 | pau brasil
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | saint-joseph
# Processing Record 40 of Set 4 | sikasso
# Processing Record 41 of Set 4 | kapurthala
# Processing Record 42 of Set 4 | vyshkov
# Processing Record 43 of Set 4 | henties bay
# Processing Record 44 of Set 4 | umzimvubu
# umzimvubu city not found. Skipping...
# Processing Record 45 of Set 4 | taltal
# Processing Record 46 of Set 4 | alta floresta
# Processing Record 47 of Set 4 | dalvik
# Processing Record 48 of Set 4 | evensk
# Processing Record 49 of Set 4 | tukrah
# Processing Record 0 of Set 5 | yerkoy
# Processing Record 1 of Set 5 | road town
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | ulladulla
# Processing Record 4 of Set 5 | bakel
# Processing Record 5 of Set 5 | laguna
# Processing Record 6 of Set 5 | ambon
# Processing Record 7 of Set 5 | grand river south east
# grand river south east city not found. Skipping...
# Processing Record 8 of Set 5 | poltavka
# Processing Record 9 of Set 5 | bayan
# Processing Record 10 of Set 5 | san patricio
# Processing Record 11 of Set 5 | rio gallegos
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | saldanha
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | makakilo city
# Processing Record 16 of Set 5 | harper
# Processing Record 17 of Set 5 | lincoln
# Processing Record 18 of Set 5 | salalah
# Processing Record 19 of Set 5 | cockburn town
# Processing Record 20 of Set 5 | goya
# Processing Record 21 of Set 5 | bolshoy tsaryn
# bolshoy tsaryn city not found. Skipping...
# Processing Record 22 of Set 5 | lompoc
# Processing Record 23 of Set 5 | dzaoudzi
# Processing Record 24 of Set 5 | kasongo-lunda
# Processing Record 25 of Set 5 | west bay
# Processing Record 26 of Set 5 | aplaya
# Processing Record 27 of Set 5 | hasaki
# Processing Record 28 of Set 5 | palmer
# Processing Record 29 of Set 5 | shaunavon
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | bonnyville
# Processing Record 32 of Set 5 | bereda
# Processing Record 33 of Set 5 | pampa
# Processing Record 34 of Set 5 | duartina
# Processing Record 35 of Set 5 | kieta
# Processing Record 36 of Set 5 | toyooka
# Processing Record 37 of Set 5 | san cristobal
# Processing Record 38 of Set 5 | ust-tsilma
# Processing Record 39 of Set 5 | port blair
# Processing Record 40 of Set 5 | amapa
# Processing Record 41 of Set 5 | visby
# Processing Record 42 of Set 5 | smithers
# Processing Record 43 of Set 5 | mizdah
# Processing Record 44 of Set 5 | pacific grove
# Processing Record 45 of Set 5 | dafeng
# Processing Record 46 of Set 5 | bella union
# Processing Record 47 of Set 5 | kadoma
# Processing Record 48 of Set 5 | is
# is city not found. Skipping...
# Processing Record 49 of Set 5 | las choapas
# Processing Record 0 of Set 6 | hofn
# Processing Record 1 of Set 6 | aflu
# aflu city not found. Skipping...
# Processing Record 2 of Set 6 | borogontsy
# Processing Record 3 of Set 6 | asfi
# Processing Record 4 of Set 6 | baherden
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | sao sebastiao
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | tyrma
# Processing Record 9 of Set 6 | mrirt
# mrirt city not found. Skipping...
# Processing Record 10 of Set 6 | saint-georges
# Processing Record 11 of Set 6 | catamarca
# Processing Record 12 of Set 6 | komsomolskiy
# Processing Record 13 of Set 6 | grandview
# Processing Record 14 of Set 6 | paracuru
# Processing Record 15 of Set 6 | nusaybin
# Processing Record 16 of Set 6 | yongzhou
# Processing Record 17 of Set 6 | dudinka
# Processing Record 18 of Set 6 | santa cruz
# Processing Record 19 of Set 6 | bonavista
# Processing Record 20 of Set 6 | omboue
# Processing Record 21 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 6 | vila franca do campo
# Processing Record 23 of Set 6 | ginir
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | yeppoon
# Processing Record 26 of Set 6 | kyren
# Processing Record 27 of Set 6 | alofi
# Processing Record 28 of Set 6 | sindand
# sindand city not found. Skipping...
# Processing Record 29 of Set 6 | nynashamn
# Processing Record 30 of Set 6 | oranjemund
# Processing Record 31 of Set 6 | comodoro rivadavia
# Processing Record 32 of Set 6 | healdsburg
# Processing Record 33 of Set 6 | upernavik
# Processing Record 34 of Set 6 | vaitape
# Processing Record 35 of Set 6 | vidim
# Processing Record 36 of Set 6 | oriximina
# Processing Record 37 of Set 6 | havre-saint-pierre
# Processing Record 38 of Set 6 | nioro
# Processing Record 39 of Set 6 | karasjok
# Processing Record 40 of Set 6 | flinders
# Processing Record 41 of Set 6 | marsa matruh
# Processing Record 42 of Set 6 | hihifo
# hihifo city not found. Skipping...
# Processing Record 43 of Set 6 | grindavik
# Processing Record 44 of Set 6 | lensk
# Processing Record 45 of Set 6 | halifax
# Processing Record 46 of Set 6 | vostok
# Processing Record 47 of Set 6 | presidencia roque saenz pena
# Processing Record 48 of Set 6 | esperance
# Processing Record 49 of Set 6 | burkhala
# burkhala city not found. Skipping...
# Processing Record 0 of Set 7 | faya
# Processing Record 1 of Set 7 | severo-kurilsk
# Processing Record 2 of Set 7 | axim
# Processing Record 3 of Set 7 | bijawar
# Processing Record 4 of Set 7 | marsh harbour
# Processing Record 5 of Set 7 | dekar
# Processing Record 6 of Set 7 | ust-kamchatsk
# ust-kamchatsk city not found. Skipping...
# Processing Record 7 of Set 7 | necochea
# Processing Record 8 of Set 7 | sept-iles
# Processing Record 9 of Set 7 | muravlenko
# Processing Record 10 of Set 7 | kangaatsiaq
# Processing Record 11 of Set 7 | ambilobe
# Processing Record 12 of Set 7 | novikovo
# Processing Record 13 of Set 7 | gravelbourg
# Processing Record 14 of Set 7 | grudziadz
# Processing Record 15 of Set 7 | coahuayana
# Processing Record 16 of Set 7 | skibbereen
# Processing Record 17 of Set 7 | ostrovnoy
# Processing Record 18 of Set 7 | natal
# Processing Record 19 of Set 7 | kijang
# Processing Record 20 of Set 7 | cruzeiro do sul
# Processing Record 21 of Set 7 | mendi
# Processing Record 22 of Set 7 | vestmannaeyjar
# Processing Record 23 of Set 7 | itoman
# Processing Record 24 of Set 7 | cascais
# Processing Record 25 of Set 7 | richards bay
# Processing Record 26 of Set 7 | tommot
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | stawell
# Processing Record 29 of Set 7 | samalaeulu
# samalaeulu city not found. Skipping...
# Processing Record 30 of Set 7 | saint-augustin
# Processing Record 31 of Set 7 | altay
# Processing Record 32 of Set 7 | whitehorse
# Processing Record 33 of Set 7 | bathsheba
# Processing Record 34 of Set 7 | santa vitoria do palmar
# Processing Record 35 of Set 7 | colorado springs
# Processing Record 36 of Set 7 | mahebourg
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | vernon
# Processing Record 39 of Set 7 | mawlaik
# Processing Record 40 of Set 7 | mahibadhoo
# Processing Record 41 of Set 7 | quatre cocos
# Processing Record 42 of Set 7 | samusu
# samusu city not found. Skipping...
# Processing Record 43 of Set 7 | stornoway
# Processing Record 44 of Set 7 | granada
# Processing Record 45 of Set 7 | moose factory
# Processing Record 46 of Set 7 | santiago del estero
# Processing Record 47 of Set 7 | takoradi
# Processing Record 48 of Set 7 | butembo
# Processing Record 49 of Set 7 | dongkan
# Processing Record 0 of Set 8 | touros
# Processing Record 1 of Set 8 | labuan
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | la libertad
# Processing Record 5 of Set 8 | haibowan
# haibowan city not found. Skipping...
# Processing Record 6 of Set 8 | somerset
# Processing Record 7 of Set 8 | usinsk
# Processing Record 8 of Set 8 | roald
# Processing Record 9 of Set 8 | plettenberg bay
# Processing Record 10 of Set 8 | sur
# Processing Record 11 of Set 8 | marzuq
# Processing Record 12 of Set 8 | ewo
# Processing Record 13 of Set 8 | canto do buriti
# Processing Record 14 of Set 8 | ilulissat
# Processing Record 15 of Set 8 | mimongo
# Processing Record 16 of Set 8 | owando
# Processing Record 17 of Set 8 | huilong
# Processing Record 18 of Set 8 | sterling
# Processing Record 19 of Set 8 | khorixas
# Processing Record 20 of Set 8 | byron bay
# Processing Record 21 of Set 8 | gazojak
# Processing Record 22 of Set 8 | fortuna
# Processing Record 23 of Set 8 | namtsy
# Processing Record 24 of Set 8 | morgan city
# Processing Record 25 of Set 8 | buala
# Processing Record 26 of Set 8 | nara
# Processing Record 27 of Set 8 | benguela
# Processing Record 28 of Set 8 | oyama
# Processing Record 29 of Set 8 | waipawa
# Processing Record 30 of Set 8 | lat yao
# Processing Record 31 of Set 8 | clyde river
# Processing Record 32 of Set 8 | kenai
# Processing Record 33 of Set 8 | acajutla
# Processing Record 34 of Set 8 | hobyo
# Processing Record 35 of Set 8 | mulanje
# Processing Record 36 of Set 8 | kruisfontein
# Processing Record 37 of Set 8 | jalingo
# Processing Record 38 of Set 8 | hagen
# Processing Record 39 of Set 8 | kloulklubed
# Processing Record 40 of Set 8 | attawapiskat
# attawapiskat city not found. Skipping...
# Processing Record 41 of Set 8 | sioux lookout
# Processing Record 42 of Set 8 | moen
# Processing Record 43 of Set 8 | conceicao da barra
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | poso
# Processing Record 46 of Set 8 | san jeronimo de tunan
# san jeronimo de tunan city not found. Skipping...
# Processing Record 47 of Set 8 | jashpurnagar
# Processing Record 48 of Set 8 | gulshat
# gulshat city not found. Skipping...
# Processing Record 49 of Set 8 | abhar
# Processing Record 0 of Set 9 | mnogovershinnyy
# Processing Record 1 of Set 9 | barcelona
# Processing Record 2 of Set 9 | homer
# Processing Record 3 of Set 9 | kungurtug
# Processing Record 4 of Set 9 | poum
# Processing Record 5 of Set 9 | dinsor
# dinsor city not found. Skipping...
# Processing Record 6 of Set 9 | ornskoldsvik
# Processing Record 7 of Set 9 | mercedes
# Processing Record 8 of Set 9 | talnakh
# Processing Record 9 of Set 9 | aden
# Processing Record 10 of Set 9 | north bend
# Processing Record 11 of Set 9 | kalmunai
# Processing Record 12 of Set 9 | kedrovyy
# Processing Record 13 of Set 9 | acapulco
# Processing Record 14 of Set 9 | kinablangan
# Processing Record 15 of Set 9 | gwadar
# Processing Record 16 of Set 9 | pangkalanbuun
# Processing Record 17 of Set 9 | belaya gora
# Processing Record 18 of Set 9 | bima
# Processing Record 19 of Set 9 | yumen
# Processing Record 20 of Set 9 | nuuk
# Processing Record 21 of Set 9 | talaya
# Processing Record 22 of Set 9 | burns lake
# Processing Record 23 of Set 9 | dehui
# Processing Record 24 of Set 9 | besskorbnaya
# Processing Record 25 of Set 9 | namibe
# Processing Record 26 of Set 9 | terrace
# Processing Record 27 of Set 9 | mount gambier
# Processing Record 28 of Set 9 | wulanhaote
# wulanhaote city not found. Skipping...
# Processing Record 29 of Set 9 | azle
# Processing Record 30 of Set 9 | maturin
# Processing Record 31 of Set 9 | chokurdakh
# Processing Record 32 of Set 9 | ukiah
# Processing Record 33 of Set 9 | eucaliptus
# Processing Record 34 of Set 9 | itarema
# Processing Record 35 of Set 9 | muroto
# Processing Record 36 of Set 9 | longkou
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | gari
# Processing Record 39 of Set 9 | himora
# himora city not found. Skipping...
# Processing Record 40 of Set 9 | hay river
# Processing Record 41 of Set 9 | morondava
# Processing Record 42 of Set 9 | vicuna
# Processing Record 43 of Set 9 | dingle
# Processing Record 44 of Set 9 | klokkarvik
# klokkarvik city not found. Skipping...
# Processing Record 45 of Set 9 | flagstaff
# Processing Record 46 of Set 9 | san quintin
# Processing Record 47 of Set 9 | khuzhir
# Processing Record 48 of Set 9 | athabasca
# Processing Record 49 of Set 9 | adrar
# Processing Record 0 of Set 10 | farah
# Processing Record 1 of Set 10 | amahai
# Processing Record 2 of Set 10 | agua dulce
# Processing Record 3 of Set 10 | el badari
# el badari city not found. Skipping...
# Processing Record 4 of Set 10 | biak
# Processing Record 5 of Set 10 | hendijan
# hendijan city not found. Skipping...
# Processing Record 6 of Set 10 | pindwara
# Processing Record 7 of Set 10 | kentau
# Processing Record 8 of Set 10 | victor harbor
# Processing Record 9 of Set 10 | tilichiki
# Processing Record 10 of Set 10 | karpathos
# Processing Record 11 of Set 10 | tanshui
# tanshui city not found. Skipping...
# Processing Record 12 of Set 10 | pemba
# Processing Record 13 of Set 10 | hisor
# Processing Record 14 of Set 10 | mayor pablo lagerenza
# Processing Record 15 of Set 10 | kanashevo
# Processing Record 16 of Set 10 | kawana waters
# kawana waters city not found. Skipping...
# Processing Record 17 of Set 10 | pandan
# Processing Record 18 of Set 10 | elko
# Processing Record 19 of Set 10 | kidal
# Processing Record 20 of Set 10 | na wa
# Processing Record 21 of Set 10 | kavieng
# Processing Record 22 of Set 10 | camacha
# Processing Record 23 of Set 10 | christchurch
# Processing Record 24 of Set 10 | bharatpur
# Processing Record 25 of Set 10 | polonnaruwa
# Processing Record 26 of Set 10 | pemberton
# Processing Record 27 of Set 10 | mazagao
# Processing Record 28 of Set 10 | mapiripan
# Processing Record 29 of Set 10 | jiddah
# jiddah city not found. Skipping...
# Processing Record 30 of Set 10 | kuche
# kuche city not found. Skipping...
# Processing Record 31 of Set 10 | luanda
# Processing Record 32 of Set 10 | batagay-alyta
# Processing Record 33 of Set 10 | te anau
# Processing Record 34 of Set 10 | suntar
# Processing Record 35 of Set 10 | tessalit
# Processing Record 36 of Set 10 | kamenskoye
# kamenskoye city not found. Skipping...
# Processing Record 37 of Set 10 | wajima
# Processing Record 38 of Set 10 | mount isa
# Processing Record 39 of Set 10 | dourdan
# Processing Record 40 of Set 10 | saryshagan
# saryshagan city not found. Skipping...
# Processing Record 41 of Set 10 | azul
# Processing Record 42 of Set 10 | gayny
# Processing Record 43 of Set 10 | ust-ishim
# Processing Record 44 of Set 10 | verkhoyansk
# Processing Record 45 of Set 10 | zyryanovsk
# Processing Record 46 of Set 10 | chalan
# Processing Record 47 of Set 10 | abu dhabi
# Processing Record 48 of Set 10 | port macquarie
# Processing Record 49 of Set 10 | ye
# ye city not found. Skipping...
# Processing Record 0 of Set 11 | kasama
# Processing Record 1 of Set 11 | sinnamary
# Processing Record 2 of Set 11 | andenes
# Processing Record 3 of Set 11 | ballybofey
# Processing Record 4 of Set 11 | havelock
# Processing Record 5 of Set 11 | scottsbluff
# Processing Record 6 of Set 11 | shimoda
# Processing Record 7 of Set 11 | pasvalys
# Processing Record 8 of Set 11 | durban
# Processing Record 9 of Set 11 | nizhneyansk
# nizhneyansk city not found. Skipping...
# Processing Record 10 of Set 11 | aras
# Processing Record 11 of Set 11 | le pradet
# Processing Record 12 of Set 11 | ovada
# Processing Record 13 of Set 11 | aykhal
# Processing Record 14 of Set 11 | grimari
# grimari city not found. Skipping...
# Processing Record 15 of Set 11 | sorland
# Processing Record 16 of Set 11 | nome
# Processing Record 17 of Set 11 | deputatskiy
# Processing Record 18 of Set 11 | houma
# Processing Record 19 of Set 11 | pontianak
# Processing Record 20 of Set 11 | alice springs
# Processing Record 21 of Set 11 | saint-pierre
# Processing Record 22 of Set 11 | port shepstone
# Processing Record 23 of Set 11 | awash
# Processing Record 24 of Set 11 | chippewa falls
# Processing Record 25 of Set 11 | luwuk
# Processing Record 26 of Set 11 | leyland
# Processing Record 27 of Set 11 | vestmanna
# Processing Record 28 of Set 11 | mendahara
# mendahara city not found. Skipping...
# Processing Record 29 of Set 11 | bolshaya orlovka
# bolshaya orlovka city not found. Skipping...
# Processing Record 30 of Set 11 | katangli
# Processing Record 31 of Set 11 | arys
# Processing Record 32 of Set 11 | galiwinku
# galiwinku city not found. Skipping...
# Processing Record 33 of Set 11 | san estanislao
# Processing Record 34 of Set 11 | yerbogachen
# Processing Record 35 of Set 11 | srednekolymsk
# Processing Record 36 of Set 11 | srivardhan
# Processing Record 37 of Set 11 | mbini
# Processing Record 38 of Set 11 | iracoubo
# Processing Record 39 of Set 11 | sungaipenuh
# Processing Record 40 of Set 11 | isangel
# Processing Record 41 of Set 11 | bocaranga
# bocaranga city not found. Skipping...
# Processing Record 42 of Set 11 | maceio
# Processing Record 43 of Set 11 | zabol
# Processing Record 44 of Set 11 | nosy varika
# Processing Record 45 of Set 11 | gazli
# Processing Record 46 of Set 11 | eskasem
# eskasem city not found. Skipping...
# Processing Record 47 of Set 11 | jasper
# Processing Record 48 of Set 11 | anadyr
# Processing Record 49 of Set 11 | morant bay
# Processing Record 0 of Set 12 | havoysund
# Processing Record 1 of Set 12 | sao desiderio
# Processing Record 2 of Set 12 | llanes
# Processing Record 3 of Set 12 | carira
# Processing Record 4 of Set 12 | ailigandi
# Processing Record 5 of Set 12 | winburg
# Processing Record 6 of Set 12 | manaus
# Processing Record 7 of Set 12 | aktash
# Processing Record 8 of Set 12 | babanusah
# babanusah city not found. Skipping...
# Processing Record 9 of Set 12 | okha
# Processing Record 10 of Set 12 | jiwani
# Processing Record 11 of Set 12 | arkhangelskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data = {"City": city_name,
"Cloudiness": cloudiness,
"Country": country,      
"Date": date,     
"Humidity": humidity,      
"Lat": lat,           
"Lng": lng,           
"Max Temp": max_temp,     
"Wind Speed": wind_speed    
}

weather_df = pd.DataFrame(data)
weather_df.to_csv(output_data_file,index = True, header = True)
weather_df.count()
# Out:
# City          556
# Cloudiness    556
# Country       556
# Date          556
# Humidity      556
# Lat           556
# Lng           556
# Max Temp      556
# Wind Speed    556
# dtype: int64

# %%
weather_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Khatanga          99      RU  1592462926        34  71.97  102.50
# 1  Fort Atkinson           0      US  1592462926        73  42.93  -88.84
# 2    Port Alfred           0      ZA  1592463086        72 -33.59   26.89
# 3     Butaritari           2      KI  1592462927        66   3.07  172.79
# 4      Cape Town           0      ZA  1592463087        58 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     59.02        4.70
# 1     64.00        4.29
# 2     55.99        8.28
# 3     83.57        8.57
# 4     53.60        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_lat = weather_df.Lat
y_temp = weather_df["Max Temp"]

plt.scatter(x_lat,y_temp, marker = "o", edgecolors = "black")
plt.title(f"City Latitude vs. Max Temperature ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_hum = weather_df["Humidity"]

plt.scatter(x_lat,y_hum, marker = "o", edgecolors = "black")
plt.title(f"City Latitude vs. Humidity ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_cloud = weather_df["Cloudiness"]

plt.scatter(x_lat,y_cloud, marker = "o", edgecolors = "black")
plt.title(f"City Latitude vs. Cloudiness ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_ws = weather_df["Wind Speed"]

plt.scatter(x_lat,y_ws, marker = "o", edgecolors = "black")
plt.title(f"City Latitude vs. Wind Speed ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_df_north = weather_df[weather_df["Lat"] >= 0]
weather_df_south = weather_df[weather_df["Lat"] < 0]
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 2       Port Alfred           0      ZA  1592463086        72 -33.59   26.89
# 4         Cape Town           0      ZA  1592463087        58 -33.93   18.42
# 5           Ushuaia          20      AR  1592462802        86 -54.80  -68.30
# 9         Busselton           1      AU  1592462929        91 -33.65  115.33
# 11   Port Elizabeth           0      ZA  1592462929        81 -33.92   25.57
# ..              ...         ...     ...         ...       ...    ...     ...
# 540     Nosy Varika          76      MG  1592463275        76 -20.58   48.53
# 546   São Desidério           0      BR  1592463276        89 -12.36  -44.97
# 548          Carira           7      BR  1592463278       100 -10.36  -37.70
# 550         Winburg           2      ZA  1592463279        68 -28.52   27.01
# 551          Manaus          20      BR  1592462990        94  -3.10  -60.02
#
#      Max Temp  Wind Speed
# 2       55.99        8.28
# 4       53.60        5.82
# 5       33.80        4.70
# 9       57.00       16.02
# 11      50.00        3.36
# ..        ...         ...
# 540     67.33        6.42
# 546     63.39        5.01
# 548     64.67        6.15
# 550     44.60        9.15
# 551     77.00        2.24
#
# [183 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_lat_n = weather_df_north.Lat
y_temp_n = weather_df_north["Max Temp"]

plt.scatter(x_lat_n,y_temp_n)
plt.title(f"Northern Hemisphere\nCity Latitude vs. Max Temperature ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_lat_s = weather_df_south.Lat
y_temp_s = weather_df_south["Max Temp"]

plt.scatter(x_lat_s,y_temp_s)
plt.title(f"Southern Hemisphere\nCity Latitude vs. Max Temperature ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_hum_n = weather_df_north["Humidity"]

plt.scatter(x_lat_n,y_hum_n)
plt.title(f"Northern Hemisphere\nCity Latitude vs. Humidity (%) ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_hum_s = weather_df_south["Humidity"]

plt.scatter(x_lat_s,y_hum_s)
plt.title(f"Southern Hemisphere\nCity Latitude vs. Humidity (%) ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_cloud_n = weather_df_north["Cloudiness"]

plt.scatter(x_lat_n,y_cloud_n)
plt.title(f"Northern Hemisphere\nCity Latitude vs. Cloudiness (%) ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_cloud_s = weather_df_south["Cloudiness"]

plt.scatter(x_lat_s,y_cloud_s)
plt.title(f"Southern Hemisphere\nCity Latitude vs. Cloudiness (%) ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_wind_n = weather_df_north["Wind Speed"]

plt.scatter(x_lat_n,y_wind_n)
plt.title(f"Northern Hemisphere\nCity Latitude vs. Wind Speed (mph) ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_wind_s = weather_df_south["Wind Speed"]

plt.scatter(x_lat_s,y_wind_s)
plt.title(f"Southern Hemisphere\nCity Latitude vs. Wind Speed (mph) ({analysis_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()
