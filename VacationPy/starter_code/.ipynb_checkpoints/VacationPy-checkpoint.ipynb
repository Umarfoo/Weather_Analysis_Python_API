# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !jupyter nbextension enable --py --sys-prefix gmaps
# !pip install gmaps
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK
# Requirement already satisfied: gmaps in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (0.9.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: ipython>=5.3.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (7.12.0)
# Requirement already satisfied: six in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (1.14.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: ipython-genutils in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: decorator in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->gmaps) (4.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (3.0.3)
# Requirement already satisfied: setuptools>=18.5 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (46.0.0.post20200309)
# Requirement already satisfied: jedi>=0.10 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.14.1)
# Requirement already satisfied: pickleshare in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: pygments in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (2.5.2)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.4)
# Requirement already satisfied: wcwidth in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.8)
# Requirement already satisfied: parso>=0.5.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->gmaps) (0.6.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.1)
# Requirement already satisfied: jupyter-client in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: nbconvert in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: jinja2 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.1)
# Requirement already satisfied: Send2Trash in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: prometheus-client in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: pyzmq>=17 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (18.1.1)
# Requirement already satisfied: terminado>=0.8.1 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.7)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: testpath in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: bleach in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: defusedxml in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.2.0)
# Requirement already satisfied: webencodings in /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Defining file path to data file
data_file = "../../WeatherPy/output_data/cities.csv"

# Converting csv to dataframe
weather_df = pd.read_csv(data_file)

# Dropping extra index column
weather_df = weather_df.drop(columns = ["Unnamed: 0"])

# Dropping missing value rows
weather_df.dropna(inplace = True)

# Printing dataframe top 5 rows
weather_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Khatanga          99      RU  1592462926        34  71.97  102.50
# 1  Fort Atkinson           0      US  1592462926        73  42.93  -88.84
# 2    Port Alfred           0      ZA  1592463086        72 -33.59   26.89
# 3     Butaritari           2      KI  1592462927        66   3.07  172.79
# 4      Cape Town           0      ZA  1592463087        58 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     59.02        4.70
# 1     64.00        4.29
# 2     55.99        8.28
# 3     83.57        8.57
# 4     53.60        5.82

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configuring gmaps
gmaps.configure(api_key=g_key)

# %%
# Defining variables and storing relevent data for mapping
location = weather_df[["Lat","Lng"]]
humidity_weights = weather_df["Humidity"].astype(float)

# Setting intensity to maximum value of humidity
intensity = weather_df["Humidity"].max()

# Creating figure of google map, defining zoom level and center around Austin City
fig_h = gmaps.figure(zoom_level=3,center=(30.26,-97.74))

# Defining humidity layer
humidity_layer = gmaps.heatmap_layer(location, weights = humidity_weights, dissipating = False, max_intensity = intensity, point_radius = 1)

# Adding humidity layer to gmap
fig_h.add_layer(humidity_layer)

# Printing results
fig_h
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Following results were achieved:

# %% [markdown]
# ![title](../Images/heat_map2.png)

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down the DataFrame to find your ideal weather condition. For example:
# A max temperature lower than 80 degrees but higher than 70.
# Wind speed less than 10 mph.
# Zero cloudiness.

# Defining conditions of dataframe and only fetching relvent rows
narrowed_city_df = weather_df.loc[(weather_df["Max Temp"] < 80) & 
                                  (weather_df["Wind Speed"] < 10) & 
                                  (weather_df["Cloudiness"] == 0),:]

# Printing shortlisted dataframe
narrowed_city_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1   Fort Atkinson           0      US  1592462926        73  42.93  -88.84
# 2     Port Alfred           0      ZA  1592463086        72 -33.59   26.89
# 4       Cape Town           0      ZA  1592463087        58 -33.93   18.42
# 8        Zhigansk           0      RU  1592462928        41  66.77  123.37
# 10         Dikson           0      RU  1592462929        94  73.51   80.55
#
#     Max Temp  Wind Speed
# 1      64.00        4.29
# 2      55.99        8.28
# 4      53.60        5.82
# 8      72.73        4.32
# 10     32.65        9.37

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Creating lists to add data to hotel_df
hot_names = []
hot_lat = []
hot_lng = []

# %%
# Creating base URL for api to retreive data
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Establishing params to for api
params = {
    "type" : "hotel",
    "radius": 5000,
    "key":g_key   
}

# Running forloop for adding hotel names in the dataframe
for index, row in narrowed_city_df.iterrows():
    
    # Extracting latitude and longitude from rows
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Combining lat and lng data in f string to run in api
    locat = f"{lat},{lng}"
    
    # Adding location parameters to params
    params["location"] = locat   
    
    # Running api to extract data
    response = requests.get(base_url, params = params).json()
    results = response["results"]
    
    # Appending hotel name to narrowed city dataframe and add lat & lng to list variables
    try:
        narrowed_city_df.loc[index,"Hotel Name"] = results[1]['name']
        hot_names.append(results[1]['name'])
        hot_lat.append(response["results"][1]["geometry"]["location"]["lat"])
        hot_lng.append(response["results"][1]["geometry"]["location"]["lng"])
    
    # Printing if city not found
    except IndexError:
        print(f"{locat} no found")
# Out:
# /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 36.25,-121.25 no found

# %%
# Adding data to hotel_df and converting to dataframe
hotel_df = {
    "Hotel Name": hot_names,
    "Lat":hot_lat,
    "Lng":hot_lng
}
hotel_df = pd.DataFrame(hotel_df)

# Printing hotel_df dataframe
hotel_df.head()
# Out:
#                             Hotel Name        Lat         Lng
# 0              Fireside Dinner Theatre  42.914312  -88.848441
# 1                   The Halyards Hotel -33.594329   26.893248
# 2    Southern Sun Waterfront Cape Town -33.915763   18.423496
# 3  Kapital Meditsinskoye Strakhovaniye  66.770325  123.377624
# 4      Council urban settlements Dixon  73.506120   80.516583

# %%
# Droping cities with hotel name not found
narrowed_city_df.dropna(inplace=True)

# Printing finalized dataframe
narrowed_city_df.head()
# Out:
# /Users/umarfarooq/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 1   Fort Atkinson           0      US  1592462926        73  42.93  -88.84
# 2     Port Alfred           0      ZA  1592463086        72 -33.59   26.89
# 4       Cape Town           0      ZA  1592463087        58 -33.93   18.42
# 8        Zhigansk           0      RU  1592462928        41  66.77  123.37
# 10         Dikson           0      RU  1592462929        94  73.51   80.55
#
#     Max Temp  Wind Speed                           Hotel Name
# 1      64.00        4.29              Fireside Dinner Theatre
# 2      55.99        8.28                   The Halyards Hotel
# 4      53.60        5.82    Southern Sun Waterfront Cape Town
# 8      72.73        4.32  Kapital Meditsinskoye Strakhovaniye
# 10     32.65        9.37      Council urban settlements Dixon

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
#locations = narrowed_city_df[["Lat", "Lng"]]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Adding markers with infobox and using hotel lat & lng data for markers
markers_location = locations
markers = gmaps.marker_layer(markers_location, info_box_content= hotel_info)

# Display Map
fig_h
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Following results were achieved:

# %% [markdown]
# ![title](../Images/final_map2.png)
